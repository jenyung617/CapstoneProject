# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',95)
pd.set_option('display.max_rows',None)
import pickle
import re
import datetime
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# Opening the pickled file
f = open('df6.pkl', 'rb')
df6 = pickle.load(f)
f.close()

# %%
# Opening the pickled file
f = open('df5.pkl', 'rb')
df5 = pickle.load(f)
f.close()

# %%
df6.head()
# Out:
#         date  store_number  sale_dollars
# 0 2012-03-27          2534         94.02
# 1 2015-08-25          4924         33.00
# 2 2013-02-21          4652         40.48
# 3 2014-01-27          4794          8.99
# 4 2013-09-09          2647         80.94

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20095649 entries, 0 to 20095648
# Data columns (total 3 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   store_number  int64
#  2   sale_dollars  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 613.3 MB

# %%
df6['store_number'] = df6['store_number'].astype('category')

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20095649 entries, 0 to 20095648
# Data columns (total 3 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   store_number  category
#  2   sale_dollars  float64
# dtypes: category(1), datetime64[ns](1), float64(1)
# memory usage: 498.4 MB

# %%
X=df6.groupby([pd.Grouper(key='date', freq='M'), 'store_number'])['sale_dollars'].sum()

# %%
Y=X.reset_index().pivot(index='date', columns='store_number', values='sale_dollars')

# %%
Y.columns
# Out:
# CategoricalIndex([2106, 2113, 2130, 2132, 2152, 2161, 2178, 2190, 2191, 2200,
#                   ...
#                   9928, 9929, 9930, 9931, 9932, 9934, 9936, 9937, 9938, 9946],
#                  categories=[2106, 2113, 2130, 2132, 2152, 2161, 2178, 2190, ...], ordered=False, name='store_number', dtype='category', length=2506)

# %%
Y.loc[:,2500].plot(kind='line')

# %%
X2=X.reset_index()

# %%
X2['month'] = X2.date.dt.month

# %%
S=pd.pivot_table(X2, index='month', columns='store_number', values='sale_dollars', aggfunc='mean')

# %%
S.head()
# Out:
# store_number           2106         2113           2130      2132       2152  \
# month
# 1              96197.675556  6050.527778   82190.126667  12619.20  5962.1740
# 2              94216.032222  4968.933333   97031.082222  17813.64  6404.3620
# 3             101089.765556  6568.591250  106626.107778  13040.13  6896.5300
# 4              96877.883333  6996.051250   79423.936667  13712.98  8074.4175
# 5             106042.963333  6875.158750   84518.315556       NaN  8078.6600
#
# store_number     2161          2178           2190          2191  \
# month
# 1             6110.59  17351.972222  155668.092222  76145.032222
# 2             5180.26  19481.962222  167132.603333  95064.298889
# 3             7482.77  23996.854444  193011.040000  95615.660000
# 4             7669.52  22357.262222  199345.260000  94236.927778
# 5             5379.66  27423.870000  193937.195556  79634.167778
#
# store_number          2200        2205          2228          2233  \
# month
# 1             16418.738889  17893.1825  15498.967778  22337.944444
# 2             16889.410000  14736.1375  15654.501111  17903.494444
# 3             16542.052222  17699.9650  19735.697778  19680.150000
# 4             18462.004444  17316.4550  17979.184444  23109.727778
# 5             20582.646667  17130.0300  18369.120000  29914.521111
#
# store_number          2238          2248     2260          2285       2290  \
# month
# 1              2901.232222  35878.136667  2046.18  46617.917778  34715.676
# 2              5028.746667  46991.427778      NaN  50502.745556  42793.828
# 3              8225.065556  46298.652222      NaN  48728.002222  43974.678
# 4              8137.232222  52366.830000      NaN  57989.787778  42994.080
# 5             34612.398750  54076.388889      NaN  59354.253333  48351.320
#
# store_number         2327        2353        2367          2413     2422  \
# month
# 1             6010.452857  27839.3500  11981.3575  64752.281667  2872.01
# 2             6380.837143  39783.8540  13275.8750  60366.938333      NaN
# 3             7474.330000  35277.2200  16851.0700  66064.143333      NaN
# 4             6417.660000  42091.6025  14288.3275  70038.683333      NaN
# 5             7048.385714  35666.9025  14653.5600  61447.545000      NaN
#
# store_number         2445          2448         2459          2460  \
# month
# 1             5635.196667  17262.751429  6209.914444  15069.498571
# 2             5195.861111  15709.402857  5278.662222  22729.975000
# 3             6881.014444  16633.205714  6461.253333  24183.645000
# 4             6146.665556  15602.705714  6052.052222  23481.046667
# 5             6740.276667  17625.232857  7336.746667  28183.421667
#
# store_number          2465         2475          2478        2487      2498  \
# month
# 1             58901.276667  10062.11750  16444.596667  35852.4200  2253.200
# 2             58631.981111   8969.09625  19147.265556  31182.1125  2281.980
# 3             64490.405556  10461.49250  15738.894444  30294.0225  1912.304
# 4             66120.494444   9596.32750  20502.321250  29460.5150  2251.648
# 5             68726.412222   9093.06125  22150.352500  41461.0800  2138.276
#
# store_number           2500           2501           2502       2503  \
# month
# 1             101345.086667  101859.751111   76168.105556   9638.465
# 2              93389.592222  112226.932222  101527.613333   9978.515
# 3              88157.162222  104761.076667   97556.460000   9130.265
# 4             114034.956667  128127.490000  153548.097778   9708.090
# 5              86769.508889  103013.401111  135256.350000  13473.045
#
# store_number          2505           2506          2507          2508  \
# month
# 1             46888.620000   89743.645556  21209.311111  61972.628889
# 2             55016.455556   94422.632222  20228.270000  60500.046667
# 3             46424.624444  109185.857778  22096.418889  80221.933333
# 4             51717.502222  107609.390000  22985.853333  66279.602222
# 5             60844.645556  127303.135556  28057.004444  80735.914444
#
# store_number          2509          2510      2511           2512  \
# month
# 1             39105.406667  21143.870000   9754.57  275608.456667
# 2             41829.032222  19904.603333  11135.39  322685.720000
# 3             42010.446667  15369.230000  18232.05  337220.663333
# 4             44710.126667  14443.246667   5412.47  360202.028889
# 5             54902.166667  22672.983333  12400.13  325161.402222
#
# store_number          2513          2514           2515  ...  6071  6072  \
# month                                                    ...
# 1             52695.053333  17781.420000   87046.111111  ...   NaN   NaN
# 2             48304.005556  18618.387778   89292.162222  ...   NaN   NaN
# 3             47064.790000  13102.713333  111790.666667  ...   NaN   NaN
# 4             52089.675556  16943.123333  117289.003333  ...   NaN   NaN
# 5             54882.652222  20425.068889  126687.973333  ...   NaN   NaN
#
# store_number  6073  6074  6075  6076  6078  6080          9001          9002  \
# month
# 1              NaN   NaN   NaN   NaN   NaN   NaN   9647.955556  13027.971111
# 2              NaN   NaN   NaN   NaN   NaN   NaN  10027.340000  12447.270000
# 3              NaN   NaN   NaN   NaN   NaN   NaN  11200.720000  15728.071429
# 4              NaN   NaN   NaN   NaN   NaN   NaN  13938.966667  18250.582500
# 5              NaN   NaN   NaN   NaN   NaN   NaN  15380.057778  23194.786667
#
# store_number      9010      9013    9014  9017     9018     9022     9023  \
# month
# 1              995.352  4520.148  181.68   NaN      NaN      NaN   766.68
# 2             1823.370  3670.310     NaN   NaN  19278.9  2321.76  1655.60
# 3             2026.660  5286.816     NaN   NaN      NaN      NaN  1425.06
# 4              803.688  4005.280     NaN   NaN      NaN      NaN      NaN
# 5             1036.680  4787.976     NaN   NaN  26190.0   414.24      NaN
#
# store_number     9031     9034     9037     9038      9039     9041     9042  \
# month
# 1             4077.00  1386.24  1327.50  45240.0  21828.96  3194.46  1290.36
# 2             1210.50      NaN   540.00  11762.4    821.10  3224.58  2528.28
# 3             4477.50      NaN  2533.50      NaN  23678.85  2304.09   687.06
# 4                 NaN      NaN   663.75      NaN    641.22  7158.09  4356.12
# 5             3893.06      NaN  1762.50  45240.0   5950.80  6201.30  1789.20
#
# store_number  9046     9901     9902       9906    9910       9911    9912  \
# month
# 1              NaN  1469.61   998.91   7093.945     NaN   8260.955     NaN
# 2              NaN  2183.28  1453.08   6249.155     NaN   9705.385  213.65
# 3              NaN  2654.46  1011.99   8992.170  125.06  11937.300  176.16
# 4              NaN  1958.04  1246.92  10602.875  177.48  13139.425  112.44
# 5              NaN  3064.00   686.64   8498.955     NaN  10358.305     NaN
#
# store_number    9913    9919  9922  9923    9925    9927   9928  9929  9930  \
# month
# 1             416.52     NaN   NaN   NaN     NaN     NaN    NaN   NaN   NaN
# 2             213.36     NaN   NaN   NaN     NaN     NaN    NaN   NaN   NaN
# 3             467.28  287.89   NaN   NaN  237.24  325.68  468.0   NaN   NaN
# 4             472.11     NaN   NaN   NaN  129.24     NaN  468.0   NaN   NaN
# 5             333.60     NaN   NaN   NaN  237.24     NaN  468.0   NaN   NaN
#
# store_number   9931  9932    9934   9936   9937  9938  9946
# month
# 1             252.0   NaN  346.56  31.14    NaN   NaN   NaN
# 2             252.0   NaN     NaN    NaN    NaN   NaN   NaN
# 3               NaN   NaN     NaN    NaN    NaN   NaN   NaN
# 4               NaN   NaN     NaN    NaN    NaN   NaN   NaN
# 5             252.0   NaN     NaN    NaN  157.5   NaN   NaN
#
# [5 rows x 2506 columns]

# %%
result=S.dropna(how='any', axis=1) # use only stores with long history

# %%
# Standardize rows
result2 = result.apply(lambda t:(t-t.mean())/t.std(), axis=0)

# %%
result2.shape
# Out:
# (12, 1975)

# %%
result2.T.head()
# Out:
# month               1         2         3         4         5         6   \
# store_number
# 2106         -0.521864 -0.790084  0.140292 -0.429796  0.810719 -0.590412
# 2113         -0.643213 -1.652165 -0.159944  0.238807  0.126034  1.651907
# 2130         -0.922607  0.666960  1.694653 -1.218884 -0.673242 -0.680688
# 2152         -1.271325 -0.940603 -0.572499  0.308471  0.311644  0.585162
# 2178         -1.378258 -0.988300 -0.161714 -0.461890  0.465703 -0.334033
#
# month               7         8         9         10        11        12
# store_number
# 2106         -1.041368  0.808283 -0.994385  1.486317 -0.728751  1.851049
# 2113          0.280482 -0.769826 -0.496930  0.295119 -0.736262  1.865991
# 2130         -0.227146  0.676744 -1.397732  1.037948  0.107079  0.936914
# 2152          0.896920  2.051333 -0.431165 -0.225696 -1.388990  0.676747
# 2178          0.284670 -0.169766 -0.887877  1.049596  0.236692  2.345178

# %% [markdown]
# ### clusters = 4

# %%
km4 = KMeans(n_clusters=4)
km4.fit(result2.T)
# Out:
# KMeans(n_clusters=4)

# %%
plt.plot(km4.cluster_centers_.T)
plt.title('4 Cluster Time Series')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
R=pca.fit_transform(result2.T)

# %%
plt.scatter(R[:,0], R[:,1], c=km4.labels_, s=1)
plt.title('K = 4')
# Out:
# Text(0.5, 1.0, 'K = 4')

# %% [markdown]
# ### clusters = 3

# %%
km3 = KMeans(n_clusters=3)
km3.fit(result2.T)
# Out:
# KMeans(n_clusters=3)

# %%
plt.plot(km3.cluster_centers_.T)
plt.title('3 Cluster Time Series')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.scatter(R[:,0], R[:,1], c=km3.labels_, s=1)
plt.title('K = 3')
# Out:
# Text(0.5, 1.0, 'K = 3')

# %%
inertia = []
for k in range(2,10):
    km3.set_params(n_clusters=k)
    km3.fit(result2.T)
    inertia.append(km3.inertia_)

# %%
plt.plot(inertia)
plt.title('Inertia Plot')
plt.xlabel('# Clusters')
# Out:
# Text(0.5, 0, '# Clusters')

# %%
# Mapping to convert to a dictionary
mapping = pd.Series(km4.labels_, index = result2.T.index)
# also could call result2.columns as this is what it is (columns are the store numbers)

# %%
set(km4.labels_)
# Out:
# {0, 1, 2, 3}

# %%
mapping = pd.DataFrame(mapping)

# %%
mapping = mapping.rename(columns = {0:'cluster'})

# %%
mapping = mapping.reset_index()

# %%
mapping.head()
# Out:
#   store_number  cluster
# 0         2106        2
# 1         2113        0
# 2         2130        2
# 3         2152        3
# 4         2178        0

# %%
df5.shape
# Out:
# (20095649, 18)

# %%
df7 = pd.merge(df5, mapping, how = 'left', on = 'store_number')

# %%
df7.head()
# Out:
#   invoice/item_number       date store_number          city zip_code  \
# 0        S04763500007 2012-03-27         2534     urbandale    50322
# 1        S27474100012 2015-08-25         4924        nashua    50658
# 2        S10731000040 2013-02-21         4652     davenport    52803
# 3        S17037900080 2014-01-27         4794    burlington    52601
# 4        S14396900023 2013-09-09         2647  cedar rapids    52411
#
#    county_number      county item_number                     item_description  \
# 0           77.0        Polk       11788                         black velvet
# 1           19.0   Chickasaw       89194  jose cuervo especial reposado flask
# 2           82.0       Scott       34449                    ketel one citroen
# 3           29.0  Des Moines       32236               seagrams extra dry gin
# 4           57.0        Linn       13038              canadian reserve whisky
#
#    state_bottle_cost  state_bottle_retail  bottles_sold  sale_dollars  \
# 0                NaN                  NaN           6.0         94.02
# 1                NaN                  NaN           4.0         33.00
# 2                NaN                  NaN           2.0         40.48
# 3                NaN                  NaN           1.0          8.99
# 4                NaN                  NaN           6.0         80.94
#
#    volume_sold_liters                                   store_name cat_name  \
# 0               10.50                  hy-vee drugtown / urbandale  whiskey
# 1                1.50                                   abby lea's  tequila
# 2                1.50                     brady mart food & liquor    vodka
# 3                0.75  smokin' joe's #17 tobacco and liquor outlet      gin
# 4               10.50            hy-vee #7 / edgewood cedar rapids  whiskey
#
#   open_store         store_type  cluster
# 0     closed        supermarket      NaN
# 1     closed       retail store      3.0
# 2       open  convenience store      3.0
# 3       open       retail store      0.0
# 4       open        supermarket      2.0

# %%
# Dropping the clusters that are NaN
# ~df5['cluster'].isna() #series of boolean values for each index, tilda will do the opposite and then index df5
# df5.head(10)[~df5.head(10)['cluster'].isna()] # notce the head() after the df5 you put the head (after both df5) - it will pull it faster,
# it is a "cheap trick" and also the ~ works as a negator to isna so will pull the non-NaNs
df7 = df7[~df7['cluster'].isna()]

# %%
df7.head()
# Out:
#   invoice/item_number       date store_number          city zip_code  \
# 1        S27474100012 2015-08-25         4924        nashua    50658
# 2        S10731000040 2013-02-21         4652     davenport    52803
# 3        S17037900080 2014-01-27         4794    burlington    52601
# 4        S14396900023 2013-09-09         2647  cedar rapids    52411
# 5        S23690800026 2015-01-28         3825    des moines    50316
#
#    county_number      county item_number                     item_description  \
# 1           19.0   Chickasaw       89194  jose cuervo especial reposado flask
# 2           82.0       Scott       34449                    ketel one citroen
# 3           29.0  Des Moines       32236               seagrams extra dry gin
# 4           57.0        Linn       13038              canadian reserve whisky
# 5           77.0        Polk       43333        captain morgan spiced rum pet
#
#    state_bottle_cost  state_bottle_retail  bottles_sold  sale_dollars  \
# 1                NaN                  NaN           4.0         33.00
# 2                NaN                  NaN           2.0         40.48
# 3                NaN                  NaN           1.0          8.99
# 4                NaN                  NaN           6.0         80.94
# 5                NaN                  NaN          48.0        153.60
#
#    volume_sold_liters                                   store_name cat_name  \
# 1                1.50                                   abby lea's  tequila
# 2                1.50                     brady mart food & liquor    vodka
# 3                0.75  smokin' joe's #17 tobacco and liquor outlet      gin
# 4               10.50            hy-vee #7 / edgewood cedar rapids  whiskey
# 5                9.60                      shop n save #2 / e 14th      rum
#
#   open_store         store_type  cluster
# 1     closed       retail store      3.0
# 2       open  convenience store      3.0
# 3       open       retail store      0.0
# 4       open        supermarket      2.0
# 5       open  convenience store      0.0

# %%
# Writing/saving as a pickled file 
# f = open('df7.pkl', 'wb')
# pickle.dump(df7, f)
# f.close()

# %%
# Looking at the df with the newly assigned clusters 
A=df7.groupby([pd.Grouper(key='date', freq='M'), 'cluster'])['sale_dollars'].sum()

# %%
B=A.reset_index().pivot(index='date', columns='cluster', values='sale_dollars')

# %%
B.columns
# Out:
# Float64Index([0.0, 1.0, 2.0, 3.0], dtype='float64', name='cluster')

# %%
B.loc[:,0.0].plot(kind='line')

# %%
B.loc[:,1.0].plot(kind='line')

# %%
B.loc[:,2.0].plot(kind='line')

# %%
B.loc[:,3.0].plot(kind='line')

# %%
# Looking at the df with the newly assigned clusters but using avg sales per store
A2=df7.groupby([pd.Grouper(key='date', freq='M'), 'cluster'])['sale_dollars'].median()

# %%
B2=A2.reset_index().pivot(index='date', columns='cluster', values='sale_dollars')

# %%
B2.columns
# Out:
# Float64Index([0.0, 1.0, 2.0, 3.0], dtype='float64', name='cluster')

# %%
B2.loc[:,0.0].plot(kind='line')
plt.ylabel('Sales (K)')
plt.xlabel('Year')
plt.title('Cluster 1: Median Order Per Store')
plt.savefig('cluster_1.png')

# %%
B2.loc[:,1.0].plot(kind='line')
plt.ylabel('Sales (K)')
plt.xlabel('Year')
plt.title('Cluster 2: Median Order Per Store')
plt.savefig('cluster_2.png')

# %%
B2.loc[:,2.0].plot(kind='line')
plt.ylabel('Sales (K)')
plt.xlabel('Year')
plt.title('Cluster 3: Median Order Per Store')
plt.savefig('cluster_3.png')

# %%
B2.loc[:,3.0].plot(kind='line')
plt.ylabel('Sales (K)')
plt.xlabel('Year')
plt.title('Cluster 4: Median Order Per Store')
plt.savefig('cluster_4.png')

# %%
# df7['item_description'].map(lambda t:mapping.get(t)).head()

# %%
# data['column number'] = data['item_description'].map(lambda t:mapping.get(t))

# %%
df7.groupby('cluster')['cat_name'].count()
# Out:
# cluster
# 0.0    7241869
# 1.0    1497063
# 2.0    7870798
# 3.0    3270061
# Name: cat_name, dtype: int64

# %%
W = df7.groupby(['cluster', 'cat_name'])['cat_name'].count().reset_index(name = 'count')

# %%
# W

# %%
W.rename(columns = {'cat_name':'Category Name', 'cluster':'Cluster'}, inplace = True)

# %%
# W.replace(index = {0.0:1, '1.0':'2', '2':'3.0', '3.0':'4.0'}, inplace = True)
W.replace({0.0:1, 1.0:2, 2.0:3, 3.0:4}, inplace = True)

# %%
# W

# %%
W2 = W.pivot(index = 'Cluster', columns = 'Category Name', values = 'count')

# %%
W2.head()
# Out:
# Category Name  accessories  brandy  cocktails  cordials liqueurs  egg nog  \
# Cluster
# 1.0                  54539  379652     196465             600346      465
# 2.0                  12641   89448      24163              85654       18
# 3.0                  66081  365596     282509             673041      705
# 4.0                  24829  232575      59268             242166       81
#
# Category Name     gin  grain alcohol     rum  schnapps  special orders  \
# Cluster
# 1.0            254854           9489  852627    391034            8913
# 2.0             42276            799  180379     55812            2507
# 3.0            310523          10843  915957    400753            9875
# 4.0            106839           3105  361526    169649            3944
#
# Category Name  spirits  tequila    vodka  whiskey
# Cluster
# 1.0              49033   343327  1801606  2299519
# 2.0               6889    59679   440370   496428
# 3.0              58960   371373  1991784  2412798
# 4.0              18572   157587   847021  1042899

# %%
W2 = W2[['whiskey', 'vodka', 'tequila', 'spirits', 'special orders', 'schnapps', 'rum', 'grain alcohol', 'gin', 'egg nog', 'cordials liqueurs', 'cocktails', 'brandy', 'accessories']]

# %%
W3 = W2.apply(lambda t: t/t.sum(), axis = 1)

# %%
W3.sum(axis=1)
# Out:
# Cluster
# 1.0    1.0
# 2.0    1.0
# 3.0    1.0
# 4.0    1.0
# dtype: float64

# %%
W3.head()
# Out:
# Category Name   whiskey     vodka   tequila   spirits  special orders  \
# Cluster
# 1.0            0.317531  0.248776  0.047409  0.006771        0.001231
# 2.0            0.331601  0.294156  0.039864  0.004602        0.001675
# 3.0            0.306551  0.253060  0.047184  0.007491        0.001255
# 4.0            0.318923  0.259023  0.048191  0.005679        0.001206
#
# Category Name  schnapps       rum  grain alcohol       gin   egg nog  \
# Cluster
# 1.0            0.053996  0.117736       0.001310  0.035192  0.000064
# 2.0            0.037281  0.120489       0.000534  0.028239  0.000012
# 3.0            0.050916  0.116374       0.001378  0.039453  0.000090
# 4.0            0.051879  0.110556       0.000950  0.032672  0.000025
#
# Category Name  cordials liqueurs  cocktails    brandy  accessories
# Cluster
# 1.0                     0.082899   0.027129  0.052425     0.007531
# 2.0                     0.057215   0.016140  0.059749     0.008444
# 3.0                     0.085511   0.035893  0.046450     0.008396
# 4.0                     0.074055   0.018124  0.071123     0.007593

# %%
sns.heatmap(W3.T, annot=True)

# %%
W3.T.style.background_gradient(cmap ='viridis').set_properties(**{'font-size': '15px'})
# Out:
# <style  type="text/css" >
#     #T_82b3a66a_4320_11eb_a151_002b678055a2row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row0_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row0_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row0_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row1_col0 {
#             background-color:  #70cf57;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row1_col1 {
#             background-color:  #b5de2b;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row1_col2 {
#             background-color:  #8bd646;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row1_col3 {
#             background-color:  #81d34d;
#             color:  #000000;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row2_col0 {
#             background-color:  #463480;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row2_col1 {
#             background-color:  #472a7a;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row2_col2 {
#             background-color:  #453581;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row2_col3 {
#             background-color:  #463480;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row3_col0 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row3_col1 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row3_col2 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row3_col3 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row4_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row4_col1 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row4_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row4_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row5_col0 {
#             background-color:  #443a83;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row5_col1 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row5_col2 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row5_col3 {
#             background-color:  #453882;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row6_col0 {
#             background-color:  #2d718e;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row6_col1 {
#             background-color:  #2d708e;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row6_col2 {
#             background-color:  #2c738e;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row6_col3 {
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row7_col0 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row7_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row7_col2 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row7_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row8_col0 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row8_col1 {
#             background-color:  #481f70;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row8_col2 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row8_col3 {
#             background-color:  #482576;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row9_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row9_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row9_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row9_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row10_col0 {
#             background-color:  #3a548c;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row10_col1 {
#             background-color:  #443b84;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row10_col2 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row10_col3 {
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row11_col0 {
#             background-color:  #481f70;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row11_col1 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row11_col2 {
#             background-color:  #482979;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row11_col3 {
#             background-color:  #481668;
#             color:  #f1f1f1;
#             font-size:  15px;
#         }    #T_82b3a66a_4320_11eb_a151_002b678055a2row12_col0 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#             font-

# %%
fig, ax = plt.subplots(figsize = (11, 6)) 
x_axis_labels = [1,2,3,4]
sns.heatmap(W3.T, cmap ='RdYlGn', linewidths = 0.30, annot = True, xticklabels=x_axis_labels) 
bottom, top = ax.get_ylim() 
ax.set_ylim(bottom + 0.5, top - 0.5)
ax.set_title('Liquor Orders by Cluster (Based on Count)', fontsize =20)
plt.savefig('box.png')

# %%
# Looking at the df with the newly assigned clusters but using avg sales per store
G1 = df7.groupby([pd.Grouper(key='date', freq='Q'), 'cluster', 'cat_name'])['sale_dollars'].median()

# %%
G1
# Out:
# date        cluster  cat_name
# 2012-03-31  0.0      accessories            89.430
#                      brandy                 33.040
#                      cocktails              58.440
#                      cordials liqueurs      56.040
#                      gin                    59.910
#                      grain alcohol          72.180
#                      rum                    68.220
#                      schnapps               38.970
#                      spirits                85.560
#                      tequila                70.590
#                      vodka                  63.600
#                      whiskey                71.040
#             1.0      accessories            71.265
#                      brandy                 45.000
#                      cocktails              24.600
#                      cordials liqueurs      37.860
#                      gin                    37.480
#                      grain alcohol          36.090
#                      rum                    51.960
#                      schnapps               33.060
#                      spirits                85.560
#                      tequila                45.000
#                      vodka                  59.520
#                      whiskey                57.330
#             2.0      accessories           169.920
#                      brandy                 40.440
#                      cocktails              63.120
#                      cordials liqueurs      59.970
#                      egg nog                74.880
#                      gin                    63.000
#                      grain alcohol         144.360
#                      rum                    81.170
#                      schnapps               53.970
#                      spirits                85.560
#                      tequila                78.260
#                      vodka                  67.020
#                      whiskey                80.940
#             3.0      accessories           161.820
#                      brandy                 39.970
#                      cocktails              55.440
#                      cordials liqueurs      52.110
#                      gin                    51.000
#                      grain alcohol          36.090
#                      rum                    63.000
#                      schnapps               37.800
#                      spirits               243.360
#                      tequila                62.920
#                      vodka                  62.280
#                      whiskey                67.860
# 2012-06-30  0.0      accessories           112.200
#                      brandy                 42.500
#                      cocktails              62.820
#                      cordials liqueurs      60.720
#                      gin                    60.900
#                      grain alcohol          74.280
#                      rum                    69.240
#                      schnapps               38.970
#                      spirits                85.560
#                      tequila                78.260
#                      vodka                  63.900
#                      whiskey                74.400
#             1.0      accessories            81.030
#                      brandy                 54.000
#                      cocktails              46.710
#                      cordials liqueurs      44.770
#                      gin                    43.020
#                      grain alcohol          36.090
#                      rum                    51.540
#                      schnapps               33.060
#                      spirits                50.720
#                      tequila                45.000
#                      vodka                  59.520
#                      whiskey                58.740
#             2.0      accessories           208.440
#                      brandy                 48.720
#                      cocktails              70.800
#                      cordials liqueurs      60.720
#                      gin                    63.900
#                      grain alcohol         148.560
#                      rum                    90.000
#                      schnapps               56.700
#                      spirits                93.780
#                      tequila                94.380
#                      vodka                  67.500
#                      whiskey                82.260
#             3.0      accessories           117.240
#                      brandy                 49.560
#                      cocktails              57.120
#                      cordials liqueurs      59.650
#                      gin                    58.560
#                      grain alcohol          37.140
#                      rum                    67.980
#                      schnapps               38.430
#                      spirits               171.120
#                      tequila                60.000
#                      vodka                  62.280
#                      whiskey                70.830
# 2012-09-30  0.0      accessories            84.960
#                      brandy                 41.640
#                      cocktails              58.440
#                      cordials liqueurs      65.900
#                      gin                    60.480
#                      grain alcohol          74.280
#                      rum                    68.720
#                      schnapps               39.980
#                      spirits                85.560
#                      tequila                81.000
#                      vodka                  63.120
#                      whiskey                76.440
#             1.0      accessories            78.880
#                      brandy                 49.260
#                      cocktails              43.860
#                      cordials liqueurs      48.850
#                      gin                    49.050
#                      grain alcohol          37.140
#                      rum                    62.100
#                      schnapps               33.000
#                      spirits                85.560
#                      tequila                47.850
#                      vodka                  61.800
#                      whiskey                61.480
#             2.0      accessories           108.360
#                      brandy                 51.760
#                      cocktails              68.760
#                      cordials liqueurs      68.390
#                      gin                    63.900
#                      grain alcohol         148.560
#                      rum                    90.000
#                      schnapps               56.700
#                      spirits                93.780
#                      tequila                92.880
#                      vodka                  70.920
#                      whiskey                84.960
#             3.0      accessories           108.360
#                      brandy                 49.560
#                      cocktails              57.120
#                      cordials liqueurs      58.560
#                      gin                    53.100
#                      grain alcohol          37.140
#                      rum                    67.800
#                      schnapps               37.480
#                      spirits                93.780
#                      tequila                61.920
#                      vodka                  62.280
#                      whiskey                70.800
# 2012-12-31  0.0      accessories           118.080
#                      brandy                 44.990
#                      cocktails              62.280
#                      cordials liqueurs      61.425
#                      egg nog                80.280
#                      gin                    61.080
#                      grain alcohol          74.280
#                      rum                    69.240
#                      schnapps               38.130
#                      special orders        118.960
#                      spirits                93.780
#                      tequila                77.970
#                      vodka                  64.200
#                      whiskey                75.000
#             1.0      accessories            90.360
#                      brandy                 49.260
#                      cocktails              31.860
#                      cordials liqueurs      50.980
#                      gin                    51.375
#                      grain alcohol          37.140
#                      rum                    68.220
#                      schnapps               33.300
#                      spirits                81.120
#                      tequila                52.320
#                      vodka                  62.280
#                      whiskey                64.480
#             2.0      accessories           188.880
#                      brandy                 57.440
#                      cocktails              63.120
#                      cordials liqueurs      69.920
#                      egg nog                80.280
#                      gin                    63.900
#                      grain alcohol         148.560
#                      rum                    90.000
#                      schnapps               60.720
#                      special orders        118.960
#                      spirits                93.780
#                      tequila                89.970
#                      vodka                  70.680
#                      whiskey                87.060
#             3.0      accessories            89.760
#                      brandy                 49.560
#                      cocktails              48.700
#                      cordials liqueurs      54.000
#                      egg nog                80.280
#                      gin                    53.640
#                      grain alcohol          49.520
#                      rum                    56.560
#                      schnapps               33.800
#                      spirits                93.780
#                      tequila                61.920
#                      vodka                  62.280
#                      whiskey                68.400
# 2013-03-31  0.0      accessories            98.940
#                      brandy                 49.260
#                      cocktails              58.440
#                      cordials liqueurs      59.600
#                      gin                    61.080
#                      grain alcohol          49.520
#                      rum                    69.240
#                      schnapps               38.970
#                      spirits                93.780
#                      tequila                77.670
#                      vodka                  64.200
#                      whiskey                71.760
#             1.0      accessories            67.250
#                      brandy                 53.980
#                      cocktails              35.430
#                      cordials liqueurs      46.600
#                      gin                    53.970
#                      grain alcohol          49.520
#                      rum                    68.220
#                      schnapps               33.300
#                      spirits                93.780
#                      tequila                47.190
#                      vodka                  62.280
#                      whiskey                62.980
#             2.0      accessories           133.500
#                      brandy                 61.000
#                      cocktails              63.120
#                      cordials liqueurs      66.720
#                      gin                    63.900
#                      grain alcohol         148.560
#                      rum                    90.000
#                      schnapps               57.000
#                      spirits                93.780
#                      tequila                88.000
#                      vodka                  67.140
#                      whiskey                83.100
#             3.0      accessories           216.720
#                      brandy                 50.460
#                      cocktails              53.160
#                      cordials liqueurs      51.480
#                      gin                    46.170
#                      grain alcohol          37.140
#                      rum                    52.480
#                      schnapps               33.060
#                      spirits                93.780
#                      tequila                62.920
#                      vodka                  62.280
#                      whiskey                64.870
# 2013-06-30  0.0      accessories            99.270
#                      brandy                 52.050
#                      cocktails              67.500
#                      cordials liqueurs      59.580
#                      gin                    61.320
#                      grain alcohol          76.500
#                      rum                    69.240
#                      schnapps               40.920
#                      spirits                93.780
#                      tequila                84.000
#                      vodka                  64.560
#                      whiskey                75.000
#             1.0      accessories            44.500
#                      brandy                 63.840
#                      cocktails              55.440
#                      cordials liqueurs      49.470
#                      gin                    58.350
#                      grain alcohol          38.250
#                      rum                    68.220
#                      schnapps               36.780
#                      special orders        231.870
#                      spirits                93.780
#                      tequila                56.220
#                      vodka                  64.200
#                      whiskey                62.980
#             2.0      accessories           209.820
#                      brandy                 59.820
#                      cocktails              73.800
#                      cordials liqueurs      60.720
#                      gin                    63.900
#                      grain alcohol         153.000
#                      rum                    94.500
#                      schnapps               63.720
#                      spirits                93.780
#                      tequila               103.960
#                      vodka                  70.920
#                      whiskey                85.320
#             3.0      accessories           216.720
#                      brandy                 56.610
#                      cocktails              55.440
#                      cordials liqueurs      51.760
#                      gin                    52.820
#                      grain alcohol          38.250
#                      rum                    61.400
#                      schnapps               37.800
#                      spirits                93.780
#                      tequila                65.220
#                      vodka                  64.200
#                      whiskey                67.140
# 2013-09-30  0.0      accessories            87.900
#                      brandy                 56.960
#                      cocktails              58.440
#                      cordials liqueurs      58.560
#                      gin                    62.280
#                      grain alcohol         153.000
#                      rum                    74.940
#                      schnapps               42.030
#                      spirits                93.780
#                      tequila                86.960
#                      vodka                  64.740
#                      whiskey                80.100
#             1.0      accessories           216.960
#                      brandy                 63.840
#                      cocktails              36.900
#                      cordials liqueurs      58.620
#                      gin                    56.220
#                      grain alcohol          59.250
#                      rum                    75.120
#                      schnapps               42.030
#                      special orders        231.870
#                      spirits                93.780
#                      tequila                58.920
#                      vodka                  64.560
#                      whiskey                75.600
#             2.0      accessories           209.820
#                      brandy                 59.820
#                      cocktails              67.440
#                      cordials liqueurs      60.720
#                      gin                    64.560
#                      grain alcohol         157.560
#                      rum                    94.500
#                      schnapps               63.360
#                      spirits                93.780
#                      tequila                98.880
#                      vodka                  71.280
#                      whiskey                88.800
#             3.0      accessories           177.360
#                      brandy                 56.610
#                      cocktails              57.120
#                      cordials liqueurs      46.600
#                      gin                    53.940
#                      grain alcohol          39.390
#                      rum                    68.220
#                      schnapps               37.800
#                      spirits                93.780
#                      tequila                73.905
#                      vodka                  64.560
#                      whiskey                68.400
# 2013-12-31  0.0      accessories           141.720
#                      brandy                 53.980
#                      cocktails              57.720
#                      cordials liqueurs      59.740
#                      egg nog                80.280
#                      gin                    63.900
#                      grain alcohol         157.560
#                      rum                    75.660
#                      schnapps               41.040
#                      special orders        118.960
#                      spirits                93.780
#                      tequila                84.000
#                      vodka                  64.740
#                      whiskey                80.280
#             1.0      accessories           153.000
#                      brandy                 63.840
#                      cocktails              55.440
#                      cordials liqueurs      57.790
#                      egg nog                80.280
#                      gin                    61.380
#                      grain alcohol         157.560
#                      rum                    77.640
#                      schnapps               40.500
#                      special orders        347.805
#                      spirits                93.780
#                      tequila                65.220
#                      vodka                  64.740
#                      whiskey                78.000
#             2.0      accessories           180.000
#                      brandy                 62.460
#                      cocktails              62.820
#                      cordials liqueurs      68.960
#                      egg nog               160.560
#                      gin                    64.020
#                      grain alcohol         157.560
#                      rum                    94.500
#                      schnapps               63.480
#                      special orders        118.960
#                      spirits                93.780
#                      tequila                94.380
#                      vodka                  71.280
#                      whiskey                89.280
#             3.0      accessories           101.265
#                      brandy                 53.980
#                      cocktails              55.440
#                      cordials liqueurs      44.700
#                      egg nog                80.280
#                      gin                    44.960
#                      grain alcohol          52.520
#                      rum                    68.220
#                      schnapps               37.800
#                      special orders        118.960
#                      spirits                59.280
#                      tequila                62.920
#                      vodka                  64.560
#                      whiskey                67.740
# 2014-03-31  0.0      accessories            94.440
#                      brandy                 63.740
#                      cocktails              58.500
#                      cordials liqueurs      56.250
#                      gin                    64.020
#                      grain alcohol         157.560
#                      rum                    75.720
#                      schnapps               45.000
#                      special orders        118.960
#                      spirits                93.780
#                      tequila                86.960
#                      vodka                  64.740
#                      whiskey                80.280
#             1.0      accessories            54.240
#                      brandy                 64.080
#                      cocktails              56.820
#                      cordials liqueurs      49.020
#                      gin                    61.200
#                      grain alcohol          52.520
#                      rum                    84.120
#                      schnapps               39.030
#                      spirits                93.780
#                      tequila                63.000
#                      vodka                  67.260
#                      whiskey                80.280
#             2.0      accessories           114.060
#                      brandy                 62.520
#                      cocktails              63.180
#                      cordials liqueurs      59.980
#                      gin                    64.020
#                      grain alcohol         157.560
#                      rum                    90.000
#                      schnapps               63.480
#                      spirits                93.780
#                      tequila                90.000
#                      vodka                  68.400
#                      whiskey                89.160
#             3.0      accessories            94.440
#                      brandy                 55.480
#                      cocktails              53.700
#                      cordials liqueurs      40.200
#                      gin                    40.920
#                      grain alcohol          39.390
#                      rum                    59.960
#                      schnapps               34.290
#                      spirits                46.890
#                      tequila                56.220
#                      vodka                  64.560
#                      whiskey                65.940
# 2014-06-30  0.0      accessories           214.380
#                      brandy                 64.480
#                      cocktails              60.840
#                      cordials liqueurs      51.760
#                      gin                    64.020
#                      grain alcohol         157.560
#                      rum                    74.940
#                      schnapps               42.000
#                      spirits                81.060
#                      tequila                81.000
#                      vodka                  64.740
#                      whiskey                79.080
#             1.0      accessories           101.220
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      54.240
#                      gin                    58.440
#                      grain alcohol          52.520
#                      rum                    90.000
#                      schnapps               42.000
#                      special orders        235.680
#                      spirits                93.780
#                      tequila                63.000
#                      vodka                  68.400
#                      whiskey                78.000
#             2.0      accessories           283.500
#                      brandy                 58.320
#                      cocktails              70.800
#                      cordials liqueurs      58.600
#                      gin                    64.560
#                      grain alcohol         157.560
#                      rum                    92.100
#                      schnapps               63.480
#                      special orders        448.080
#                      spirits                93.780
#                      tequila                91.350
#                      vodka                  69.360
#                      whiskey                88.740
#             3.0      accessories           179.460
#                      brandy                 58.410
#                      cocktails              55.500
#                      cordials liqueurs      44.640
#                      gin                    52.820
#                      grain alcohol          39.390
#                      rum                    69.060
#                      schnapps               34.290
#                      special orders        631.560
#                      spirits                59.280
#                      tequila                66.570
#                      vodka                  64.560
#                      whiskey                67.140
# 2014-09-30  0.0      accessories           107.940
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      51.480
#                      egg nog               160.560
#                      gin                    62.280
#                      grain alcohol         157.560
#                      rum                    72.000
#                      schnapps               39.950
#                      spirits                81.000
#                      tequila                81.000
#                      vodka                  64.800
#                      whiskey                80.280
#             1.0      accessories           154.380
#                      brandy                 70.560
#                      cocktails              35.970
#                      cordials liqueurs      49.020
#                      gin                    58.440
#                      grain alcohol         157.560
#                      rum                    94.500
#                      schnapps               39.030
#                      special orders        235.680
#                      spirits                81.870
#                      tequila                62.980
#                      vodka                  67.470
#                      whiskey                80.280
#             2.0      accessories           162.000
#                      brandy                 54.000
#                      cocktails              58.500
#                      cordials liqueurs      59.880
#                      egg nog                80.280
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    90.000
#                      schnapps               63.480
#                      special orders        436.080
#                      spirits                99.000
#                      tequila                85.500
#                      vodka                  69.360
#                      whiskey                89.160
#             3.0      accessories           117.000
#                      brandy                 58.520
#                      cocktails              55.500
#                      cordials liqueurs      45.000
#                      egg nog               321.120
#                      gin                    56.220
#                      grain alcohol          52.520
#                      rum                    66.180
#                      schnapps               34.290
#                      spirits                49.500
#                      tequila                69.570
#                      vodka                  64.560
#                      whiskey                68.400
# 2014-12-31  0.0      accessories           108.000
#                      brandy                 64.480
#                      cocktails              58.500
#                      cordials liqueurs      56.250
#                      egg nog               200.700
#                      gin                    61.920
#                      grain alcohol         162.000
#                      rum                    78.120
#                      schnapps               39.030
#                      special orders        168.240
#                      spirits                88.560
#                      tequila                81.000
#                      vodka                  64.800
#                      whiskey                82.260
#             1.0      accessories           107.940
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      49.020
#                      egg nog                80.280
#                      gin                    52.920
#                      grain alcohol          67.500
#                      rum                    81.000
#                      schnapps               41.250
#                      spirits                81.240
#                      tequila                63.000
#                      vodka                  64.800
#                      whiskey                78.120
#             2.0      accessories           134.280
#                      brandy                 57.960
#                      cocktails              60.840
#                      cordials liqueurs      65.960
#                      egg nog                80.280
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    90.000
#                      schnapps               63.720
#                      spirits                99.000
#                      tequila                86.980
#                      vodka                  70.740
#                      whiskey                90.000
#             3.0      accessories            98.940
#                      brandy                 53.290
#                      cocktails              54.000
#                      cordials liqueurs      43.560
#                      egg nog                13.380
#                      gin                    45.760
#                      grain alcohol          40.500
#                      rum                    60.750
#                      schnapps               33.000
#                      special orders       1263.120
#                      spirits                45.000
#                      tequila                60.900
#                      vodka                  64.560
#                      whiskey                68.040
# 2015-03-31  0.0      accessories           100.380
#                      brandy                 64.480
#                      cocktails              58.500
#                      cordials liqueurs      54.240
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    78.120
#                      schnapps               42.030
#                      spirits                71.460
#                      tequila                84.000
#                      vodka                  64.800
#                      whiskey                82.260
#             1.0      accessories            98.940
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      48.900
#                      gin                    55.140
#                      grain alcohol          89.820
#                      rum                    75.000
#                      schnapps               40.500
#                      spirits                99.000
#                      tequila                56.250
#                      vodka                  64.800
#                      whiskey                78.720
#             2.0      accessories           133.500
#                      brandy                 56.700
#                      cocktails              62.820
#                      cordials liqueurs      59.640
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    90.000
#                      schnapps               61.560
#                      spirits                88.920
#                      tequila                81.000
#                      vodka                  67.260
#                      whiskey                86.280
#             3.0      accessories           130.650
#                      brandy                 59.960
#                      cocktails              49.500
#                      cordials liqueurs      39.760
#                      gin                    37.500
#                      grain alcohol          40.500
#                      rum                    67.440
#                      schnapps               34.290
#                      spirits                44.460
#                      tequila                59.040
#                      vodka                  64.560
#                      whiskey                67.500
# 2015-06-30  0.0      accessories            94.440
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      51.480
#                      gin                    63.000
#                      grain alcohol         162.000
#                      rum                    75.000
#                      schnapps               40.000
#                      spirits                74.250
#                      tequila                94.440
#                      vodka                  65.520
#                      whiskey                82.620
#             1.0      accessories            89.700
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      55.020
#                      gin                    59.400
#                      grain alcohol         121.500
#                      rum                    75.000
#                      schnapps               45.720
#                      spirits                81.240
#                      tequila                62.280
#                      vodka                  64.800
#                      whiskey                80.415
#             2.0      accessories           221.160
#                      brandy                 56.980
#                      cocktails              63.180
#                      cordials liqueurs      55.680
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    85.900
#                      schnapps               58.500
#                      spirits               103.500
#                      tequila                92.760
#                      vodka                  68.400
#                      whiskey                86.400
#             3.0      accessories           165.360
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      43.560
#                      gin                    45.760
#                      grain alcohol          40.500
#                      rum                    70.560
#                      schnapps               34.620
#                      spirits                47.445
#                      tequila                69.040
#                      vodka                  64.560
#                      whiskey                70.800
# 2015-09-30  0.0      accessories            90.000
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      48.900
#                      gin                    62.280
#                      grain alcohol         162.000
#                      rum                    74.340
#                      schnapps               40.500
#                      special orders        238.980
#                      spirits                59.400
#                      tequila                81.000
#                      vodka                  64.800
#                      whiskey                82.620
#             1.0      accessories            63.725
#                      brandy                 59.960
#                      cocktails              57.780
#                      cordials liqueurs      46.620
#                      gin                    55.140
#                      grain alcohol         134.880
#                      rum                    81.000
#                      schnapps               39.015
#                      spirits                91.500
#                      tequila                56.250
#                      vodka                  64.800
#                      whiskey                74.250
#             2.0      accessories           142.920
#                      brandy                 51.300
#                      cocktails              62.820
#                      cordials liqueurs      58.680
#                      gin                    64.560
#                      grain alcohol         162.000
#                      rum                    81.000
#                      schnapps               58.500
#                      special orders        257.760
#                      spirits                81.240
#                      tequila                90.000
#                      vodka                  68.400
#                      whiskey                88.920
#             3.0      accessories            87.900
#                      brandy                 64.490
#                      cocktails              55.500
#                      cordials liqueurs      41.580
#                      gin                    45.760
#                      grain alcohol          40.500
#                      rum                    68.040
#                      schnapps               34.290
#                      spirits                44.050
#                      tequila                62.960
#                      vodka                  64.560
#                      whiskey                67.950
# 2015-12-31  0.0      accessories           119.280
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      58.500
#                      egg nog                66.900
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    78.120
#                      schnapps               45.720
#                      special orders        216.840
#                      spirits                83.880
#                      tequila                83.520
#                      vodka                  67.200
#                      whiskey                84.960
#             1.0      accessories            77.795
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      52.500
#                      egg nog                80.280
#                      gin                    56.250
#                      grain alcohol          54.000
#                      rum                    78.120
#                      schnapps               39.030
#                      spirits               103.500
#                      tequila                52.500
#                      vodka                  66.960
#                      whiskey                75.600
#             2.0      accessories           162.840
#                      brandy                 58.410
#                      cocktails              62.820
#                      cordials liqueurs      60.840
#                      egg nog                80.280
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    81.000
#                      schnapps               61.560
#                      special orders        142.760
#                      spirits                81.240
#                      tequila                81.780
#                      vodka                  68.400
#                      whiskey                90.000
#             3.0      accessories            83.220
#                      brandy                 58.410
#                      cocktails              54.840
#                      cordials liqueurs      42.000
#                      egg nog                80.280
#                      gin                    49.500
#                      grain alcohol          40.500
#                      rum                    70.560
#                      schnapps               34.290
#                      special orders        142.760
#                      spirits                52.780
#                      tequila                55.800
#                      vodka                  64.560
#                      whiskey                68.580
# 2016-03-31  0.0      accessories           103.440
#                      brandy                 65.940
#                      cocktails              58.500
#                      cordials liqueurs      53.970
#                      gin                    62.100
#                      grain alcohol         116.160
#                      rum                    78.120
#                      schnapps               43.560
#                      special orders         56.250
#                      spirits                81.240
#                      tequila                81.000
#                      vodka                  64.800
#                      whiskey                83.100
#             1.0      accessories           103.440
#                      brandy                 70.560
#                      cocktails              55.500
#                      cordials liqueurs      48.900
#                      gin                    58.440
#                      grain alcohol          54.000
#                      rum                    75.000
#                      schnapps               35.100
#                      special orders         44.580
#                      spirits                81.240
#                      tequila                56.250
#                      vodka                  64.800
#                      whiskey                75.570
#             2.0      accessories           170.040
#                      brandy                 56.980
#                      cocktails              63.180
#                      cordials liqueurs      58.500
#                      gin                    64.020
#                      grain alcohol         162.000
#                      rum                    81.000
#                      schnapps               56.700
#                      special orders         57.080
#                      spirits                88.920
#                      tequila                85.030
#                      vodka                  67.260
#                      whiskey                89.160
#             3.0      accessories            86.960
#                      brandy                 70.560
#                      cocktails              37.000
#                      cordials liqueurs      42.000
#                      gin                    46.500
#                      grain alcohol          40.500
#                      rum                    67.440
#                      schnapps               32.100
#                      special orders         56.625
#                      spirits                51.750
#                      tequila                56.250
#                      vodka                  62.640
#                      whiskey                67.500
# 2016-06-30  0.0      accessories            81.000
#                      brandy                 70.560
#                      cocktails              62.820
#                      cordials liqueurs      51.750
#                      gin                    64.020
#                      grain alcohol         114.060
#                      rum                    78.120
#                      schnapps               43.560
#                      special orders         74.280
#                      spirits                81.240
#                      tequila                90.000
#                      vodka                  64.800
#                      whiskey                83.160
#             1.0      accessories            59.520
#                      brandy                 72.000
#                      cocktails              55.500
#                      cordials liqueurs      44.410
#                      gin                    58.440
#                      grain alcohol          40.500
#                      rum                    72.000
#                      schnapps               35.430
#                      special orders         59.370
#                      spirits                97.920
#                      tequila                54.000
#                      vodka                  64.800
#                      whiskey                70.080
#             2.0      accessories           117.000
#                      brandy                 56.980
#                      cocktails              73.800
#                      cordials liqueurs      56.700
#                      gin                    64.560
#                      grain alcohol         162.000
#                      rum                    87.420
#                      schnapps               51.930
#                      special orders         75.000
#                      spirits                88.560
#                      tequila                97.490
#                      vodka                  68.960
#                      whiskey                90.000
#             3.0      accessories            66.285
#                      brandy                 70.560
#                      cocktails              49.500
#                      cordials liqueurs      44.300
#                      gin                    47.250
#                      grain alcohol          40.500
#                      rum                    67.500
#                      schnapps               33.000
#                      special orders         99.000
#                      spirits                51.750
#                      tequila                62.960
#                      vodka                  63.000
#                      whiskey                67.500
# 2016-09-30  0.0      accessories            74.970
#                      brandy                 70.560
#                      cocktails              58.500
#                      cordials liqueurs      48.900
#                      gin                    61.200
#                      grain alcohol         116.160
#                      rum                    75.000
#                      schnapps               45.000
#                      special orders         48.740
#                      spirits                83.880
#                      tequila                85.040
#                      vodka                  64.800
#                      whiskey                83.160
#             1.0      accessories            56.980
#                      brandy                 72.000
#                      cocktails              48.855
#                      cordials liqueurs      41.040
#                      gin                    58.440
#                      grain alcohol          60.750
#                      rum                    74.340
#                      schnapps               32.670
#                      special orders         21.360
#                      spirits                81.000
#                      tequila                49.500
#                      vodka                  64.800
#                      whiskey                67.830
#             2.0      accessories            94.440
#                      brandy                 53.280
# ...
#                      whiskey                80.820
#             2.0      accessories           105.040
#                      brandy                 70.560
#                      cocktails              78.660
#                      cordials liqueurs      60.000
#                      gin                    67.500
#                      rum                   103.980
#                      schnapps               58.500
#                      special orders         77.980
#                      spirits               103.500
#                      tequila               111.480
#                      vodka                  75.000
#                      whiskey                94.680
#             3.0      accessories            79.480
#                      brandy                102.000
#                      cocktails              51.240
#                      cordials liqueurs      43.560
#                      gin                    59.400
#                      rum                    70.560
#                      schnapps               38.970
#                      special orders        142.560
#                      spirits                68.250
#                      tequila                69.570
#                      vodka                  64.560
#                      whiskey                73.920
# 2019-09-30  0.0      accessories           148.560
#                      brandy                 96.840
#                      cocktails              66.600
#                      cordials liqueurs      56.250
#                      gin                    64.020
#                      rum                    81.540
#                      schnapps               59.050
#                      special orders         80.640
#                      spirits                90.000
#                      tequila               103.480
#                      vodka                  67.500
#                      whiskey                90.000
#             1.0      accessories           166.500
#                      brandy                 96.660
#                      cocktails              58.500
#                      cordials liqueurs      43.560
#                      gin                    58.440
#                      rum                    70.560
#                      schnapps               39.000
#                      special orders         42.300
#                      spirits                52.520
#                      tequila                65.250
#                      vodka                  64.800
#                      whiskey                81.000
#             2.0      accessories           166.500
#                      brandy                 70.560
#                      cocktails              78.660
#                      cordials liqueurs      57.240
#                      gin                    66.780
#                      rum                    94.500
#                      schnapps               51.960
#                      special orders         42.300
#                      spirits               103.500
#                      tequila                99.000
#                      vodka                  74.220
#                      whiskey                94.500
#             3.0      accessories           144.000
#                      brandy                106.500
#                      cocktails              45.180
#                      cordials liqueurs      42.720
#                      gin                    59.400
#                      rum                    68.040
#                      schnapps               38.970
#                      special orders        100.020
#                      spirits                81.000
#                      tequila                71.250
#                      vodka                  64.560
#                      whiskey                74.970
# 2019-12-31  0.0      accessories           112.500
#                      brandy                 96.660
#                      cocktails              66.600
#                      cordials liqueurs      68.190
#                      gin                    65.960
#                      rum                    88.080
#                      schnapps               58.500
#                      special orders         75.000
#                      spirits                90.000
#                      tequila               116.940
#                      vodka                  68.400
#                      whiskey                94.080
#             1.0      accessories            98.940
#                      brandy                 96.660
#                      cocktails              55.560
#                      cordials liqueurs      43.560
#                      gin                    57.840
#                      rum                    71.250
#                      schnapps               39.000
#                      special orders         45.000
#                      spirits                72.000
#                      tequila                65.250
#                      vodka                  64.800
#                      whiskey                84.800
#             2.0      accessories           144.000
#                      brandy                 72.000
#                      cocktails              71.940
#                      cordials liqueurs      68.960
#                      gin                    67.480
#                      rum                    99.720
#                      schnapps               58.500
#                      special orders         56.250
#                      spirits               105.040
#                      tequila               111.060
#                      vodka                  74.400
#                      whiskey                99.240
#             3.0      accessories            89.940
#                      brandy                 98.640
#                      cocktails              39.330
#                      cordials liqueurs      41.580
#                      gin                    58.500
#                      rum                    66.020
#                      schnapps               35.430
#                      special orders         77.980
#                      spirits                65.520
#                      tequila                66.440
#                      vodka                  63.360
#                      whiskey                73.260
# 2020-03-31  0.0      accessories           153.000
#                      brandy                 87.660
#                      cocktails              78.180
#                      cordials liqueurs      60.000
#                      gin                    64.560
#                      rum                    86.880
#                      schnapps               51.960
#                      special orders         94.980
#                      spirits                90.000
#                      tequila               111.060
#                      vodka                  67.260
#                      whiskey                94.080
#             1.0      accessories           238.440
#                      brandy                 96.660
#                      cocktails              56.640
#                      cordials liqueurs      44.300
#                      gin                    58.440
#                      rum                    72.000
#                      schnapps               38.970
#                      special orders         33.750
#                      spirits                85.770
#                      tequila                65.220
#                      vodka                  64.800
#                      whiskey                85.500
#             2.0      accessories           163.080
#                      brandy                 72.000
#                      cocktails              78.660
#                      cordials liqueurs      61.560
#                      gin                    65.960
#                      rum                   103.980
#                      schnapps               58.500
#                      special orders         81.000
#                      spirits               103.500
#                      tequila               107.250
#                      vodka                  74.400
#                      whiskey                99.000
#             3.0      accessories           135.000
#                      brandy                101.640
#                      cocktails              41.400
#                      cordials liqueurs      42.660
#                      gin                    59.400
#                      rum                    66.130
#                      schnapps               35.430
#                      special orders        153.000
#                      spirits                87.360
#                      tequila                65.250
#                      vodka                  62.280
#                      whiskey                72.000
# 2020-06-30  0.0      accessories           104.880
#                      brandy                 98.760
#                      cocktails              78.660
#                      cordials liqueurs      58.500
#                      gin                    66.000
#                      rum                    90.000
#                      schnapps               51.960
#                      special orders        126.000
#                      spirits                90.000
#                      tequila               108.000
#                      vodka                  68.400
#                      whiskey                94.080
#             1.0      accessories           132.780
#                      brandy                115.440
#                      cocktails              78.660
#                      cordials liqueurs      48.000
#                      gin                    60.750
#                      rum                    79.130
#                      schnapps               45.000
#                      special orders         81.000
#                      spirits               103.500
#                      tequila                76.150
#                      vodka                  65.040
#                      whiskey                93.560
#             2.0      accessories           132.780
#                      brandy                 85.680
#                      cocktails              78.660
#                      cordials liqueurs      63.000
#                      gin                    78.080
#                      rum                   103.980
#                      schnapps               58.500
#                      special orders        124.740
#                      spirits               103.500
#                      tequila               121.440
#                      vodka                  82.800
#                      whiskey               106.200
#             3.0      accessories            78.660
#                      brandy                115.440
#                      cocktails              52.440
#                      cordials liqueurs      42.520
#                      gin                    59.400
#                      rum                    67.440
#                      schnapps               38.970
#                      special orders        117.000
#                      spirits                90.000
#                      tequila                79.635
#                      vodka                  64.560
#                      whiskey                75.360
# 2020-09-30  0.0      accessories           134.520
#                      brandy                101.640
#                      cocktails              78.660
#                      cordials liqueurs      63.780
#                      gin                    70.560
#                      rum                   103.980
#                      schnapps               67.500
#                      special orders         96.960
#                      spirits                90.000
#                      tequila               121.440
#                      vodka                  71.160
#                      whiskey                94.080
#             1.0      accessories           148.560
#                      brandy                107.940
#                      cocktails              58.500
#                      cordials liqueurs      44.970
#                      gin                    59.400
#                      rum                    74.340
#                      schnapps               51.945
#                      special orders         83.820
#                      spirits                90.000
#                      tequila                74.250
#                      vodka                  64.800
#                      whiskey                90.000
#             2.0      accessories           135.000
#                      brandy                 90.000
#                      cocktails              78.660
#                      cordials liqueurs      68.020
#                      gin                    80.640
#                      rum                   108.000
#                      schnapps               67.500
#                      special orders         91.200
#                      spirits               103.500
#                      tequila               125.160
#                      vodka                  81.000
#                      whiskey               105.000
#             3.0      accessories           105.000
#                      brandy                115.440
#                      cocktails              58.500
#                      cordials liqueurs      43.560
#                      gin                    60.750
#                      rum                    69.060
#                      schnapps               43.560
#                      special orders        133.920
#                      spirits                90.000
#                      tequila                85.500
#                      vodka                  64.560
#                      whiskey                82.260
# 2020-12-31  0.0      accessories           121.070
#                      brandy                101.640
#                      cocktails              78.660
#                      cordials liqueurs      72.960
#                      gin                    70.560
#                      rum                   103.980
#                      schnapps               64.950
#                      special orders         85.500
#                      spirits                96.830
#                      tequila               126.000
#                      vodka                  68.400
#                      whiskey                94.200
#             1.0      accessories            98.960
#                      brandy                115.440
#                      cocktails              63.180
#                      cordials liqueurs      56.220
#                      gin                    59.400
#                      rum                    74.340
#                      schnapps               48.750
#                      special orders         42.750
#                      spirits                90.000
#                      tequila                90.750
#                      vodka                  64.560
#                      whiskey                94.080
#             2.0      accessories           148.560
#                      brandy                 98.940
#                      cocktails              78.660
#                      cordials liqueurs      76.660
#                      gin                    74.250
#                      rum                   108.000
#                      schnapps               67.500
#                      special orders         87.750
#                      spirits               110.250
#                      tequila               135.000
#                      vodka                  77.280
#                      whiskey               110.300
#             3.0      accessories            90.000
#                      brandy                115.440
#                      cocktails              51.780
#                      cordials liqueurs      46.860
#                      gin                    60.750
#                      rum                    67.500
#                      schnapps               39.000
#                      special orders         85.500
#                      spirits                90.000
#                      tequila                95.980
#                      vodka                  64.560
#                      whiskey                85.500
# Name: sale_dollars, dtype: float64

# %%
G3 = G1.reset_index().pivot(index='date', columns='cluster', values='sale_dollars')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-80d3e42d0e1f> in <module>
# ----> 1 G3 = G1.reset_index().pivot(index='date', columns='cluster', values='sale_dollars')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     448         else:
#     449             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 450     return indexed.unstack(columns)
#     451
#     452
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3548         from pandas.core.reshape.reshape import unstack
#    3549
# -> 3550         return unstack(self, level, fill_value)
#    3551
#    3552     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     412         if is_extension_array_dtype(obj.dtype):
#     413             return _unstack_extension_series(obj, level, fill_value)
# --> 414         unstacker = _Unstacker(
#     415             obj.values,
#     416             obj.index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     139
#     140         self._make_sorted_values_labels()
# --> 141         self._make_selectors()
#     142
#     143     def _make_sorted_values_labels(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     177
#     178         if mask.sum() < len(self.index):
# --> 179             raise ValueError("Index contains duplicate entries, cannot reshape")
#     180
#     181         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
G3.head()

# %%
G3.loc[:,0.0].plot(kind='line')
plt.ylabel('Sales (K)')
plt.xlabel('Year')
plt.title('Cluster 1: Average Sales Per Store')

# %%
df7.head()

# %%
S1 = df7.groupby([pd.Grouper(key='date', freq='Q'), 'cluster', 'cat_name', 'item_description'])['sale_dollars'].mean().reset_index(name = 'mean')

# %%
S1.head()

# %%
S1.pivot(index = 'cluster', columns = 'cat_name', values = 'mean')

# %%
S2 = df7.groupby([pd.Grouper(key='date', freq='Q'), 'store_type', 'cat_name'])['sale_dollars'].mean().reset_index(name = 'mean')

# %%
S2.head()

# %%
S2 = df7.groupby([pd.Grouper(key='date', freq='Y'), 'cluster', 'cat_name'])['sale_dollars'].sum().reset_index(name = 'sum')

# %%
S2.shape

# %%
#liquor_cat.loc[liquor_cat.category_name == 'NaN'] 
S3 = S2.loc[S2.cluster == 2.0]

# %%
S3

# %%
S4a = S3.loc[S3.date == '2020-09-30']

# %%
S5a = S3.loc[S3.date == '2019-09-30']

# %%
S6a = S3.loc[S3.date == '2018-09-30']

# %%
# S7 = S3.loc[S3.date == '2019-09-30']

# %%
# S8 = S4.append(S5)

# %%
# S8 = S8.append(S6)

# %%
S8a = S4a.append(S5a)

# %%
S8a =  S8a.append(S6a)

# %%
S8a.drop(columns = ['cluster'], axis = 1, inplace = True)

# %%
S8a.to_csv('waterfall.csv')

# %%
# A2=S8.groupby([pd.Grouper(key='date', freq='M'), 'cluster'])['sale_dollars'].median()

# %%
# S8.plot(kind='line')

# %%
# import plotly.graph_objects as go

# fig = go.Figure(go.Waterfall(
#     name = "20", orientation = "v",
#     measure = ["total", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"],
#     x = ["Q3FY19", "Whiskey", "Vodka", "Tequila", "Spirits", "Special Orders", "Schnapps", "Rum", "Gin", "Cordials Liqueurs", "Cocktails", "Brandy", "Accessories", "Q3FY20"],
#     textposition = "outside",
#     text = ["30M", "+$612k", "+$677k", "+$546k", "+$183k", "+$85k", "+$114k", "+$196k", "+$7k", "+$246k", "+$183k", "+$180k", "-$15k" "$33M"],
#     y = [0, 3084800, 3139400, 3157600, 3166100, 3177500, 3197100, 3197900, 3222500, 3240700, 3258700, 3257200, 3257200],
#     connector = {"line":{"color":"rgb(63, 63, 63)"}},
# ))

# fig.update_layout(
#         title = "Profit and loss statement 2018",
#         showlegend = True
# )

# fig.show()

# %%
A=df7.groupby([pd.Grouper(key='date', freq='M'), 'cluster'])['sale_dollars'].sum()

# %%
pd.pivot_table(A, index='month', columns='store', values='sale_dollars', aggfunc='mean')
